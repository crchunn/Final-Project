# %%
import pandas as pd
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
data_csv = "data.csv"
# Read with Pandas
data_df = pd.read_csv('data/data.csv')
# data_df.head()

# %%
data_df.drop(data_df[data_df.year < 2000].index, inplace=True)

# %%
data_df = data_df.reset_index(drop=True)
# data_df

# %%
del data_df['id']
data_df
# Out:
#        acousticness                             artists  danceability  \
# 0           0.97200                     ['David Bauer']         0.567
# 1           0.32100                      ['Etta James']         0.821
# 2           0.00659                       ['Quasimoto']         0.706
# 3           0.00390                     ['Millencolin']         0.368
# 4           0.12200                      ['Steve Chou']         0.501
# ...             ...                                 ...           ...
# 41651       0.17300              ['DripReport', 'Tyga']         0.875
# 41652       0.01670  ['Leon Bridges', 'Terrace Martin']         0.719
# 41653       0.53800               ['Kygo', 'Oh Wonder']         0.514
# 41654       0.07140       ['Cash Cash', 'Andy Grammer']         0.646
# 41655       0.10900                  ['Ingrid Andress']         0.512
#
#        duration_ms  energy  explicit  instrumentalness  key  liveness  \
# ...

# %%
del data_df['release_date']
data_df
# Out:
#        acousticness                             artists  danceability  \
# 0           0.97200                     ['David Bauer']         0.567
# 1           0.32100                      ['Etta James']         0.821
# 2           0.00659                       ['Quasimoto']         0.706
# 3           0.00390                     ['Millencolin']         0.368
# 4           0.12200                      ['Steve Chou']         0.501
# ...             ...                                 ...           ...
# 41651       0.17300              ['DripReport', 'Tyga']         0.875
# 41652       0.01670  ['Leon Bridges', 'Terrace Martin']         0.719
# 41653       0.53800               ['Kygo', 'Oh Wonder']         0.514
# 41654       0.07140       ['Cash Cash', 'Andy Grammer']         0.646
# 41655       0.10900                  ['Ingrid Andress']         0.512
#
#        duration_ms  energy  explicit  instrumentalness  key  liveness  \
# ...

# %%
data_df['artists'] =  data_df['artists'].apply(lambda x: x.replace('[','').replace(']','')) 
data_df.head()
# Out:
#    acousticness        artists  danceability  duration_ms  energy  explicit  \
# 0       0.97200  'David Bauer'         0.567       313293   0.227         0
# 1       0.32100   'Etta James'         0.821       360240   0.418         0
# 2       0.00659    'Quasimoto'         0.706       202507   0.602         1
# 3       0.00390  'Millencolin'         0.368       173360   0.977         0
# 4       0.12200   'Steve Chou'         0.501       344200   0.511         0
#
#    instrumentalness  key  liveness  loudness  mode                   name  \
# 0          0.601000   10     0.110   -13.441     1      Shout to the Lord
# 1          0.000372    9     0.222    -9.841     0               Miss You
# 2          0.000138   11     0.400    -8.306     0              Real Eyes
# 3          0.000000   11     0.350    -2.757     0  Penguins & Polarbears
# 4          0.000000    7     0.279    -9.836     0                     黃昏
#
#    popularity  speechiness    tempo  valence  year
# ...

# %%
import os

# %%
data_df.to_csv('dataD.csv')

# %%
dataA_df = data_df

# %%
del dataA_df['artists']
dataA_df

# %%
del dataA_df['name']
dataA_df

# %%
# dataA_df.to_csv('dataA.csv')

# %%
genre_csv = "data_by_genres.csv"
# Read with Pandas
genre_df = pd.read_csv('data/data_by_genres.csv')
genre_df

# %%
year_csv = 'data_by_year.csv'
year_df = pd.read_csv('data/data_by_year.csv')
# year_df

# %%
year_df.drop(year_df[year_df.year < 2000].index, inplace=True)
year_df

# %%
dataY_df = year_df

# %%
dataY_df.to_csv('dataY.csv')

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

results = sp.search(q='taylor swift', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 cardigan
# 1 exile (feat. Bon Iver)
# 2 the 1
# 3 august
# 4 betty
# 5 the last great american dynasty
# 6 You Need To Calm Down
# 7 invisible string
# 8 my tears ricochet
# 9 The Man
# 10 Lover
# 11 mirrorball
# 12 seven
# 13 illicit affairs
# 14 ME! (feat. Brendon Urie of Panic! At The Disco)
# 15 this is me trying
# 16 mad woman
# 17 peace
# 18 Delicate
# 19 epiphany

# %%
def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

# %%
def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set()  # to avoid dups
    albums.sort(key=lambda album: album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            #print('ALBUM: %s', name)
            seen.add(name)
    return seen

# %%
artist_name = 'Pink'
print(artist_name)
artist_id = get_artist(artist_name)
# Out:
# Pink

# %%
artist_id['name']
# Out:
# 'Pink Floyd'

# %%
artist_id['id']
# Out:
# '0k17h0D3J5VfsdmQ1iZtE9'

# %%
artist_albums = show_artist_albums(artist_id)

# %%
list(artist_albums)
# Out:
# ['More (Original Film Sountrack) [2011 - Remaster] [2011 Remastered Version]',
#  'The Later Years: 1987-2019',
#  'Pulse',
#  'Delicate Sound of Thunder (Live)',
#  'Ummagumma (2011 Remastered Version)',
#  'A Saucerful of Secrets',
#  'The Final Cut',
#  'Ummagumma',
#  'The Endless River',
#  'The Division Bell',
#  'Atom Heart Mother',
#  'Animals (2011 Remastered Version)',
#  'Wish You Were Here',
#  'A Momentary Lapse Of Reason (2011 Remastered Version)',
#  'The Final Cut (2011 Remastered Version)',
#  'Obscured by Clouds',
#  'The Wall',
#  'The Later Years',
#  'The Piper At The Gates Of Dawn [2011 - Remaster] (2011 Remastered Version)',
#  'The Piper at the Gates of Dawn',
#  'The Wall (Remastered)',
#  'Wish You Were Here [Remastered] (Remastered Version)',
#  'A Momentary Lapse of Reason',
#  'The Dark Side Of The Moon [Remastered] (Remastered Version)',
#  'Obscured By Clouds (2011 Remastered Version)',
#  'Meddle (2011 Remastered Version)',
#  'Pulse (Live)',
# ...

# %%
    <div class="row">
      {% for movie in movies %}
      <div class="card" style="width: 18rem;">
        <div class="card-body">
          <h5 class="card-title">{{ movie.title }}</h5>
          <p class="card-text">{{ movie.synopsis }}</p>
          <a href="{{ movie.imdb_link }}" class="card-link">IMDB page</a>
        </div>
      </div>
      {% endfor %}
    </div>

# %%
results = sp.search(q='taylor swift', limit = 20)
look = spotify.artist_top_tracks(results)

for track in look['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()

# %%
weekly50_csv = "viral-us-weekly-latest.csv"
# Read with Pandas
weekly50_df = pd.read_csv('data/viral-us-weekly-latest.csv')
weekly50_df

# %%
weekly200_csv = "regional-us-weekly-latest.csv"
# Read with Pandas
weekly200_df = pd.read_csv('data/regional-us-weekly-latest.csv')
weekly200_df

# %%
world200_csv = "regional-global-daily-latest.csv"
# Read with Pandas
world200_df = pd.read_csv('data/regional-global-daily-latest.csv')
world200_df
