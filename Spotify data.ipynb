# %%
import pandas as pd

# %%
data_csv = "data.csv"
# Read with Pandas
data_df = pd.read_csv(data_csv)
# data_df.head()

# %%
data_df.drop(data_df[data_df.year < 2000].index, inplace=True)

# %%
data_df = data_df.reset_index(drop=True)
# data_df

# %%
del data_df['id']
data_df
# Out:
#        acousticness                             artists  danceability  \
# 0           0.97200                     ['David Bauer']         0.567
# 1           0.32100                      ['Etta James']         0.821
# 2           0.00659                       ['Quasimoto']         0.706
# 3           0.00390                     ['Millencolin']         0.368
# 4           0.12200                      ['Steve Chou']         0.501
# ...             ...                                 ...           ...
# 41651       0.17300              ['DripReport', 'Tyga']         0.875
# 41652       0.01670  ['Leon Bridges', 'Terrace Martin']         0.719
# 41653       0.53800               ['Kygo', 'Oh Wonder']         0.514
# 41654       0.07140       ['Cash Cash', 'Andy Grammer']         0.646
# 41655       0.10900                  ['Ingrid Andress']         0.512
#
#        duration_ms  energy  explicit  instrumentalness  key  liveness  \
# ...

# %%
del data_df['release_date']
data_df
# Out:
#        acousticness                             artists  danceability  \
# 0           0.97200                     ['David Bauer']         0.567
# 1           0.32100                      ['Etta James']         0.821
# 2           0.00659                       ['Quasimoto']         0.706
# 3           0.00390                     ['Millencolin']         0.368
# 4           0.12200                      ['Steve Chou']         0.501
# ...             ...                                 ...           ...
# 41651       0.17300              ['DripReport', 'Tyga']         0.875
# 41652       0.01670  ['Leon Bridges', 'Terrace Martin']         0.719
# 41653       0.53800               ['Kygo', 'Oh Wonder']         0.514
# 41654       0.07140       ['Cash Cash', 'Andy Grammer']         0.646
# 41655       0.10900                  ['Ingrid Andress']         0.512
#
#        duration_ms  energy  explicit  instrumentalness  key  liveness  \
# ...

# %%
import os

# %%
# data_df.to_csv('dataD.csv')

# %%
genre_csv = "data_by_genres.csv"
# Read with Pandas
genre_df = pd.read_csv(genre_csv)
genre_df
# Out:
#               genres  acousticness  danceability   duration_ms    energy  \
# 0              432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1                 []      0.679245      0.521473  2.298526e+05  0.401522
# 2         a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3           abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4     abstract beats      0.353347      0.694400  2.338244e+05  0.613400
# ...              ...           ...           ...           ...       ...
# 2659            zolo      0.218600      0.560365  2.675453e+05  0.611985
# 2660         zouglou      0.124000      0.834000  2.951470e+05  0.674000
# 2661            zouk      0.233181      0.752762  2.951100e+05  0.627238
# 2662     zouk riddim      0.052700      0.776000  2.293330e+05  0.656000
# 2663          zydeco      0.347767      0.596992  1.788379e+05  0.603610
#
#       instrumentalness  liveness   loudness  speechiness       tempo  \
# ...

# %%
year_csv = 'data_by_year.csv'
year_df = pd.read_csv(year_csv)
# year_df

# %%
year_df.drop(year_df[year_df.year < 2000].index, inplace=True)
year_df
# Out:
#     year  acousticness  danceability    duration_ms    energy  \
# 79  2000      0.286654      0.589039  242958.072000  0.622223
# 80  2001      0.270392      0.585933  241011.540000  0.638172
# 81  2002      0.275409      0.578628  239810.235500  0.651352
# 82  2003      0.247379      0.576633  245057.708000  0.666178
# 83  2004      0.264210      0.572262  239908.288500  0.660553
# 84  2005      0.246817      0.576301  238882.838000  0.659767
# 85  2006      0.266284      0.568445  236364.348500  0.657830
# 86  2007      0.241804      0.564830  242951.749500  0.673011
# 87  2008      0.241118      0.583410  239900.875000  0.675861
# 88  2009      0.245269      0.566857  238880.798000  0.680766
# 89  2010      0.228712      0.577811  243543.909500  0.693696
# 90  2011      0.239382      0.559822  236586.656000  0.671269
# 91  2012      0.236197      0.571695  242556.937500  0.669811
# 92  2013      0.241969      0.578874  239570.822500  0.656467
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="SPOTIPY_CLIENT_ID",
                                                           client_secret="SPOTIPY_CLIENT-SECRET"))

results = sp.search(q='taylor swift', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-26-00b36660a1ce> in <module>
#       2                                                            client_secret="SPOTIPY_CLIENT-SECRET"))
#       3
# ----> 4 results = sp.search(q='taylor swift', limit=20)
#       5 for idx, track in enumerate(results['tracks']['items']):
#       6     print(idx, track['name'])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in search(self, q, limit, offset, type, market)
#     536         """
#     537         return self._get(
# --> 538             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     539         )
#     540
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     282             kwargs.update(args)
#     283
# ...

# %%
# import spotipy
from spotipy.oauth2 import SpotifyOAuth
from time import sleep

scope = "user-read-playback-state,user-modify-playback-state"
sp = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(scope=scope))

# Shows playing devices
res = sp.devices()
pprint(res)

# Change track
sp.start_playback(uris=['spotify:track:6gdLoMygLsgktydTQ71b15'])

# Change volume
sp.volume(100)
sleep(2)
sp.volume(50)
sleep(2)
sp.volume(100)
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-25-9221a6f9c4ae> in <module>
#       4
#       5 scope = "user-read-playback-state,user-modify-playback-state"
# ----> 6 sp = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(scope=scope))
#       7
#       8 # Shows playing devices
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\oauth2.py in __init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser)
#     271         super(SpotifyOAuth, self).__init__(requests_session)
#     272
# --> 273         self.client_id = client_id
#     274         self.client_secret = client_secret
#     275         self.redirect_uri = redirect_uri
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\oauth2.py in client_id(self, val)
# ...
