# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
music_df = pd.read_csv('dataD.csv')
music_df.head()
# Out:
#    Unnamed: 0  acousticness          artists  danceability  duration_ms  \
# 0           0       0.97200  ['David Bauer']         0.567       313293
# 1           1       0.32100   ['Etta James']         0.821       360240
# 2           2       0.00659    ['Quasimoto']         0.706       202507
# 3           3       0.00390  ['Millencolin']         0.368       173360
# 4           4       0.12200   ['Steve Chou']         0.501       344200
#
#    energy  explicit  instrumentalness  key  liveness  loudness  mode  \
# 0   0.227         0          0.601000   10     0.110   -13.441     1
# 1   0.418         0          0.000372    9     0.222    -9.841     0
# 2   0.602         1          0.000138   11     0.400    -8.306     0
# 3   0.977         0          0.000000   11     0.350    -2.757     0
# 4   0.511         0          0.000000    7     0.279    -9.836     0
#
#                     name  popularity  speechiness    tempo  valence  year
# 0      Shout to the Lord          47       0.0290  136.123   0.0396  2000
# 1               Miss You          51       0.0407  117.382   0.8030  2000
# 2              Real Eyes          44       0.3420   89.692   0.4790  2000
# 3  Penguins & Polarbears          52       0.1270  165.889   0.5480  2000
# 4                     黃昏          53       0.0291   78.045   0.1130  2000

# %%
del music_df['artists']
music_df
# Out:
#        Unnamed: 0  acousticness  danceability  duration_ms  energy  explicit  \
# 0               0       0.97200         0.567       313293   0.227         0
# 1               1       0.32100         0.821       360240   0.418         0
# 2               2       0.00659         0.706       202507   0.602         1
# 3               3       0.00390         0.368       173360   0.977         0
# 4               4       0.12200         0.501       344200   0.511         0
# ...           ...           ...           ...          ...     ...       ...
# 41651       41651       0.17300         0.875       163800   0.443         1
# 41652       41652       0.01670         0.719       167468   0.385         0
# 41653       41653       0.53800         0.514       180700   0.539         0
# 41654       41654       0.07140         0.646       167308   0.761         0
# 41655       41655       0.10900         0.512       214787   0.428         0
#
#        instrumentalness  key  liveness  loudness  mode  \
# 0              0.601000   10    0.1100   -13.441     1
# 1              0.000372    9    0.2220    -9.841     0
# 2              0.000138   11    0.4000    -8.306     0
# 3              0.000000   11    0.3500    -2.757     0
# 4              0.000000    7    0.2790    -9.836     0
# ...                 ...  ...       ...       ...   ...
# 41651          0.000032    1    0.0891    -7.461     1
# 41652          0.031300    8    0.1110   -10.907     1
# 41653          0.002330    7    0.1080    -9.332     1
# 41654          0.000000    1    0.2220    -2.557     1
# 41655          0.000000    0    0.1050    -7.387     1
#
#                                  name  popularity  speechiness    tempo  \
# 0                   Shout to the Lord          47       0.0290  136.123
# 1                            Miss You          51       0.0407  117.382
# 2                           Real Eyes          44       0.3420   89.692
# 3               Penguins & Polarbears          52       0.1270  165.889
# 4                                  黃昏          53       0.0291   78.045
# ...                               ...         ...          ...      ...
# 41651   Skechers (feat. Tyga) - Remix          75       0.1430  100.012
# 41652  Sweeter (feat. Terrace Martin)          64       0.0403  128.000
# 41653                How Would I Know          70       0.1050  123.700
# 41654                     I Found You          70       0.0385  129.916
# 41655           More Hearts Than Mine          65       0.0271   80.588
#
#        valence  year
# 0       0.0396  2000
# 1       0.8030  2000
# 2       0.4790  2000
# 3       0.5480  2000
# 4       0.1130  2000
# ...        ...   ...
# 41651   0.3060  2020
# 41652   0.2700  2020
# 41653   0.1530  2020
# 41654   0.4720  2020
# 41655   0.3660  2020
#
# [41656 rows x 17 columns]

# %%
del music_df['name']
music_df
# Out:
#        Unnamed: 0  acousticness  danceability  duration_ms  energy  explicit  \
# 0               0       0.97200         0.567       313293   0.227         0
# 1               1       0.32100         0.821       360240   0.418         0
# 2               2       0.00659         0.706       202507   0.602         1
# 3               3       0.00390         0.368       173360   0.977         0
# 4               4       0.12200         0.501       344200   0.511         0
# ...           ...           ...           ...          ...     ...       ...
# 41651       41651       0.17300         0.875       163800   0.443         1
# 41652       41652       0.01670         0.719       167468   0.385         0
# 41653       41653       0.53800         0.514       180700   0.539         0
# 41654       41654       0.07140         0.646       167308   0.761         0
# 41655       41655       0.10900         0.512       214787   0.428         0
#
#        instrumentalness  key  liveness  loudness  mode  popularity  \
# 0              0.601000   10    0.1100   -13.441     1          47
# 1              0.000372    9    0.2220    -9.841     0          51
# 2              0.000138   11    0.4000    -8.306     0          44
# 3              0.000000   11    0.3500    -2.757     0          52
# 4              0.000000    7    0.2790    -9.836     0          53
# ...                 ...  ...       ...       ...   ...         ...
# 41651          0.000032    1    0.0891    -7.461     1          75
# 41652          0.031300    8    0.1110   -10.907     1          64
# 41653          0.002330    7    0.1080    -9.332     1          70
# 41654          0.000000    1    0.2220    -2.557     1          70
# 41655          0.000000    0    0.1050    -7.387     1          65
#
#        speechiness    tempo  valence  year
# 0           0.0290  136.123   0.0396  2000
# 1           0.0407  117.382   0.8030  2000
# 2           0.3420   89.692   0.4790  2000
# 3           0.1270  165.889   0.5480  2000
# 4           0.0291   78.045   0.1130  2000
# ...            ...      ...      ...   ...
# 41651       0.1430  100.012   0.3060  2020
# 41652       0.0403  128.000   0.2700  2020
# 41653       0.1050  123.700   0.1530  2020
# 41654       0.0385  129.916   0.4720  2020
# 41655       0.0271   80.588   0.3660  2020
#
# [41656 rows x 16 columns]

# %%
del music_df['Unnamed: 0']
music_df
# Out:
#        acousticness  danceability  duration_ms  energy  explicit  \
# 0           0.97200         0.567       313293   0.227         0
# 1           0.32100         0.821       360240   0.418         0
# 2           0.00659         0.706       202507   0.602         1
# 3           0.00390         0.368       173360   0.977         0
# 4           0.12200         0.501       344200   0.511         0
# ...             ...           ...          ...     ...       ...
# 41651       0.17300         0.875       163800   0.443         1
# 41652       0.01670         0.719       167468   0.385         0
# 41653       0.53800         0.514       180700   0.539         0
# 41654       0.07140         0.646       167308   0.761         0
# 41655       0.10900         0.512       214787   0.428         0
#
#        instrumentalness  key  liveness  loudness  mode  popularity  \
# 0              0.601000   10    0.1100   -13.441     1          47
# 1              0.000372    9    0.2220    -9.841     0          51
# 2              0.000138   11    0.4000    -8.306     0          44
# 3              0.000000   11    0.3500    -2.757     0          52
# 4              0.000000    7    0.2790    -9.836     0          53
# ...                 ...  ...       ...       ...   ...         ...
# 41651          0.000032    1    0.0891    -7.461     1          75
# 41652          0.031300    8    0.1110   -10.907     1          64
# 41653          0.002330    7    0.1080    -9.332     1          70
# 41654          0.000000    1    0.2220    -2.557     1          70
# 41655          0.000000    0    0.1050    -7.387     1          65
#
#        speechiness    tempo  valence  year
# 0           0.0290  136.123   0.0396  2000
# 1           0.0407  117.382   0.8030  2000
# 2           0.3420   89.692   0.4790  2000
# 3           0.1270  165.889   0.5480  2000
# 4           0.0291   78.045   0.1130  2000
# ...            ...      ...      ...   ...
# 41651       0.1430  100.012   0.3060  2020
# 41652       0.0403  128.000   0.2700  2020
# 41653       0.1050  123.700   0.1530  2020
# 41654       0.0385  129.916   0.4720  2020
# 41655       0.0271   80.588   0.3660  2020
#
# [41656 rows x 15 columns]

# %%
X = music_df.drop("mode", axis=1)
y = music_df["mode"]
print(X.shape, y.shape)
# Out:
# (41656, 14) (41656,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=14))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               1500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 11,802
# Trainable params: 11,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 31242 samples
# Epoch 1/60
# 31242/31242 - 6s - loss: 0.6184 - accuracy: 0.6727
# Epoch 2/60
# 31242/31242 - 4s - loss: 0.6117 - accuracy: 0.6737
# Epoch 3/60
# 31242/31242 - 4s - loss: 0.6080 - accuracy: 0.6734
# Epoch 4/60
# 31242/31242 - 6s - loss: 0.6049 - accuracy: 0.6766
# Epoch 5/60
# 31242/31242 - 4s - loss: 0.6017 - accuracy: 0.6812
# Epoch 6/60
# 31242/31242 - 4s - loss: 0.5978 - accuracy: 0.6885
# Epoch 7/60
# 31242/31242 - 4s - loss: 0.5939 - accuracy: 0.6953
# Epoch 8/60
# 31242/31242 - 4s - loss: 0.5907 - accuracy: 0.7002
# Epoch 9/60
# 31242/31242 - 4s - loss: 0.5875 - accuracy: 0.7064
# Epoch 10/60
# 31242/31242 - 4s - loss: 0.5842 - accuracy: 0.7078
# Epoch 11/60
# 31242/31242 - 4s - loss: 0.5825 - accuracy: 0.7076
# Epoch 12/60
# 31242/31242 - 5s - loss: 0.5810 - accuracy: 0.7086
# Epoch 13/60
# 31242/31242 - 5s - loss: 0.5794 - accuracy: 0.7107
# Epoch 14/60
# 31242/31242 - 4s - loss: 0.5785 - accuracy: 0.7105
# Epoch 15/60
# 31242/31242 - 4s - loss: 0.5777 - accuracy: 0.7117
# Epoch 16/60
# 31242/31242 - 5s - loss: 0.5762 - accuracy: 0.7101
# Epoch 17/60
# 31242/31242 - 4s - loss: 0.5756 - accuracy: 0.7134
# Epoch 18/60
# 31242/31242 - 4s - loss: 0.5744 - accuracy: 0.7131
# Epoch 19/60
# 31242/31242 - 4s - loss: 0.5737 - accuracy: 0.7130
# Epoch 20/60
# 31242/31242 - 4s - loss: 0.5729 - accuracy: 0.7134
# Epoch 21/60
# 31242/31242 - 5s - loss: 0.5723 - accuracy: 0.7122
# Epoch 22/60
# 31242/31242 - 5s - loss: 0.5708 - accuracy: 0.7149
# Epoch 23/60
# 31242/31242 - 5s - loss: 0.5700 - accuracy: 0.7152
# Epoch 24/60
# 31242/31242 - 5s - loss: 0.5696 - accuracy: 0.7158
# Epoch 25/60
# 31242/31242 - 6s - loss: 0.5682 - accuracy: 0.7166
# Epoch 26/60
# 31242/31242 - 6s - loss: 0.5675 - accuracy: 0.7173
# Epoch 27/60
# 31242/31242 - 5s - loss: 0.5680 - accuracy: 0.7154
# Epoch 28/60
# 31242/31242 - 5s - loss: 0.5670 - accuracy: 0.7173
# Epoch 29/60
# 31242/31242 - 5s - loss: 0.5661 - accuracy: 0.7165
# Epoch 30/60
# 31242/31242 - 4s - loss: 0.5654 - accuracy: 0.7180
# Epoch 31/60
# 31242/31242 - 4s - loss: 0.5638 - accuracy: 0.7180
# Epoch 32/60
# 31242/31242 - 5s - loss: 0.5622 - accuracy: 0.7177
# Epoch 33/60
# 31242/31242 - 6s - loss: 0.5621 - accuracy: 0.7195
# Epoch 34/60
# 31242/31242 - 24s - loss: 0.5611 - accuracy: 0.7210
# Epoch 35/60
# 31242/31242 - 8s - loss: 0.5600 - accuracy: 0.7205
# Epoch 36/60
# 31242/31242 - 6s - loss: 0.5588 - accuracy: 0.7219
# Epoch 37/60
# 31242/31242 - 6s - loss: 0.5585 - accuracy: 0.7199
# Epoch 38/60
# 31242/31242 - 6s - loss: 0.5574 - accuracy: 0.7229
# Epoch 39/60
# 31242/31242 - 9s - loss: 0.5568 - accuracy: 0.7217
# Epoch 40/60
# 31242/31242 - 5s - loss: 0.5557 - accuracy: 0.7216
# Epoch 41/60
# 31242/31242 - 6s - loss: 0.5553 - accuracy: 0.7229
# Epoch 42/60
# 31242/31242 - 5s - loss: 0.5544 - accuracy: 0.7242
# Epoch 43/60
# 31242/31242 - 7s - loss: 0.5529 - accuracy: 0.7236
# Epoch 44/60
# 31242/31242 - 6s - loss: 0.5518 - accuracy: 0.7250
# Epoch 45/60
# 31242/31242 - 6s - loss: 0.5515 - accuracy: 0.7264
# Epoch 46/60
# 31242/31242 - 6s - loss: 0.5511 - accuracy: 0.7264
# Epoch 47/60
# 31242/31242 - 6s - loss: 0.5506 - accuracy: 0.7220
# Epoch 48/60
# 31242/31242 - 6s - loss: 0.5495 - accuracy: 0.7268
# Epoch 49/60
# 31242/31242 - 5s - loss: 0.5486 - accuracy: 0.7263
# Epoch 50/60
# 31242/31242 - 6s - loss: 0.5477 - accuracy: 0.7279
# Epoch 51/60
# 31242/31242 - 6s - loss: 0.5469 - accuracy: 0.7279
# Epoch 52/60
# 31242/31242 - 5s - loss: 0.5455 - accuracy: 0.7281
# Epoch 53/60
# 31242/31242 - 4s - loss: 0.5456 - accuracy: 0.7248
# Epoch 54/60
# 31242/31242 - 4s - loss: 0.5444 - accuracy: 0.7292
# Epoch 55/60
# 31242/31242 - 5s - loss: 0.5430 - accuracy: 0.7299
# Epoch 56/60
# 31242/31242 - 6s - loss: 0.5433 - accuracy: 0.7288
# Epoch 57/60
# 31242/31242 - 5s - loss: 0.5422 - accuracy: 0.7281
# Epoch 58/60
# 31242/31242 - 6s - loss: 0.5411 - accuracy: 0.7334
# Epoch 59/60
# 31242/31242 - 5s - loss: 0.5406 - accuracy: 0.7313
# Epoch 60/60
# 31242/31242 - 5s - loss: 0.5394 - accuracy: 0.7313

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10414/1 - 1s - loss: 0.6394 - accuracy: 0.7108
# Normal Neural Network - Loss: 0.5809174851513147, Accuracy: 0.7107739448547363

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: [0 1 1 1 1 0 0 0 1 1]
# Actual Labels: [1, 1, 0, 1, 1, 1, 0, 1, 0, 1]
